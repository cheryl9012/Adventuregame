# %% [markdown]
# <a href="https://colab.research.google.com/github/cheryl9012/Adventuregame/blob/main/mad_lib_python_project.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# take input from user
name = input("Enter the girl name:")
programming_language =input("Enter a programming language (eg: python, next.js , typescript , html): ")
mentor = input ("Enter the mentor name:")
location = input ("Enter the location : ")

#story created
print("\nHere is my little story on mad libs game!")
print(f"Along time ago, there was a girl named {name}.  ")
print(f"{name} was an inquisitive and always wanted to explore new things.")
print(f"One day, {name} decided to learn {programming_language}.")
print(f"Fortunately {name} got enroll at {location} and she found an exceptional mentor name as {name} who was an expert in {programming_language}.")
print("And so, her journey continues............!")
